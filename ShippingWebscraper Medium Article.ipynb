# %% [markdown]
# # Maritime Ports Database Builder
#
# **Ahoy there, adventurous coders and maritime enthusiasts!** <br>⚓️ Set sail on an exciting coding journey with our Maritime Ports Database Builder! <br>🚀 This Python script is your trusty shipmate to explore the vast seas of maritime data. <br>It collects essential shipping information from a maritime website and crafts a robust SQLite database using the power of SQLAlchemy.
#
# ## Features:
#
# - 🌊 Scrapes essential shipping data from a maritime website.
# - ⚓️ Constructs a robust SQLite database to store countries, ports, and detailed port data.
# - 📚 Respects the website's "robots.txt" rules for ethical web scraping.
# - 🗺️ Guided navigation through the code with a warm and friendly tone.
# - 🌟 Perfect for developers and maritime enthusiasts seeking valuable maritime insights.
#
# Let our database builder be your guiding light to maritime wisdom. 🌍⛵️ Hoist those coding sails and set off on a marvelous journey together! Happy coding and bon voyage! 🚢🌊
#
# Feel free to customize the summary according to your preferences and any additional features you'd like to highlight! 🎉

# %% [markdown]
# ##### Library

# %%
# Modified on 20 April 2022
import requests
from bs4 import BeautifulSoup as bs
import time
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# CREATES THE SQL DATABASE
from sqlalchemy.exc import IntegrityError
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine, Column, Integer, String, Float, Date, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import declarative_base
Base = declarative_base()

# %%
#Database Name : 
Database = 'ShippingDatabase.db'

# %% [markdown]
# ##### Database Classes

# %%
class Country(Base):
    __tablename__ = 'country'
    countryCode = Column(String, primary_key=True)
    countryName = Column(String)
    numPorts = Column(Float)

class Port(Base):
    __tablename__ = 'port'
    countryCode = Column(String, ForeignKey('country.countryCode'))
    ckey = Column(String, primary_key=True)
    name = Column(String)

class Port_Data(Base):
    __tablename__ = 'port_data'
    id = Column(Integer, primary_key=True)
    ckey = Column(String, ForeignKey('port.ckey'))
    Address = Column(String)
    Port_Authority = Column(String)
    Phone = Column(String)
    Fax = Column(String)
    Email = Column(String)
    Coordinates = Column(String)
    Port_Type = Column(String)
    Port_Size = Column(String)
    Website = Column(String)
    Terminal = Column(String)

# %% [markdown]
# ##### Functions

# %%
def getCountries(URL, session, headers):
    Country_Data = []
    r = session.get(URL, headers=headers)
    if r.status_code == 200 : 
        soup  = bs(r.content, 'html.parser')
        select = soup.find('select', {'id':'country-content'})
        for opt in select.findAll('option')[1:]:
            Country_Data.append({
                'CountryName' : opt.text.strip(), 
                'CountryCode' : opt['value'].strip()
            })
        return Country_Data
def getPorts(countryCode, session, headers):
    shippingMAINURL = 'https://www.searates.com/maritime/ports-map/'

    data = {
        'c': countryCode
    }

    r = session.post(shippingMAINURL, data=data, headers=headers)
    if r.status_code == 200 : 
        data = r.json()
        ports = [ { 'ckey' : x['ckey'], 'name' : x['name']} for x in data['cports']]
        return {
            'numPorts' : len(data['cports']),
            'Ports' : ports
        }
    else:
        return None
def getPortData(PortCode, session, headers):

    # PortCode = 'durres_al'
    PortDataURL = f'https://www.searates.com/port/{PortCode}'

    r = session.get(PortDataURL, headers=headers)

    if r.status_code == 200:
        soup = bs(r.content, 'html.parser')
        dataTab1 = soup.find('div', {'class': 'incoterms-block__wrapper js-adaptive'})
        dataTab2 = dataTab1.find('div', {'class': 'incoterms-block__list'})

        # Find all the paragraphs with class="incoterms-block__item"
        incoterms_items = dataTab2.find_all('p', class_='incoterms-block__item')

        # Create a dictionary to store the extracted information

        info_dict = {}
        PORT_DATA = {}
        # Extract the specific information and store it in the dictionary
        for item in incoterms_items:
            span_elements = item.find_all('span', class_='incoterms-block__text')
            if len(span_elements) == 2:
                key = span_elements[0].get_text().strip()
                # Join all text elements within the span with commas
                value = ', '.join(span_elements[1].stripped_strings)
                # Replace <br/> tags with commas
                value = value.replace('<br/>', ', ')
                info_dict[key] = value

        # Print the extracted information
        for key, value in info_dict.items():
            PORT_DATA[key] = value
        return PORT_DATA
    else:
        return None

# %% [markdown]
# ##### Main Function Run

# %%
 
engine = create_engine(f'sqlite:///{Database}')
Base.metadata.create_all(engine)
## Database Variables
try:
    engine = engine
except :
    engine = create_engine(f'sqlite:///{Database}')
Session = sessionmaker(bind=engine)
db_session = Session()

## Webscraping Variables
session = requests.Session()

headers = {
        'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
    }

countries = getCountries('https://www.searates.com/maritime', session, headers)

for country in countries:
    
    Name, Code = country['CountryName'], country['CountryCode']
    print('[*] Data for :', Name)
    print('*'*50)
    country_instance = db_session.query(Country).filter_by(countryCode=Code, countryName=Name ).first()
    if not country_instance:
        country_instance = Country(countryCode=Code, countryName=Name, numPorts=0)
        try:
            db_session.add(country_instance)
            db_session.commit() 
        except : 
            engine = create_engine(f'sqlite:///{Database}')
            Session = sessionmaker(bind=engine)
            db_session = Session()
            db_session.add(country_instance)
            db_session.commit() 
            
        print('[*] Added to Database : ', country_instance)
        
    ports = getPorts(Code, session, headers)
    
    time.sleep(1) # Delay to preserve website response time.
    
    for port in ports['Ports']:
        
        portdb = db_session.query(Port).filter_by(countryCode = country_instance.countryCode, ckey=port['ckey'], name = port['name'] ).first()
        
        if not portdb:
            portdb = Port(
                countryCode = country_instance.countryCode,
                ckey = port['ckey'],
                name = port['name']
                )
            db_session.add(portdb)

            country_instance.numPorts = ports['numPorts']

            try:
                db_session.commit()
            except IntegrityError:
                db_session.rollback()
            
            print('[*] Scraping Port : {}'.format(port['name']))
            PortCode = port['ckey']
            portdata = getPortData(PortCode, session, headers)
            # Initialize default values in case a key is missing in portdata
            default_value = 'N/A'

            portdatadb = Port_Data(
                ckey=portdb.ckey,
                Address=portdata.get('Address', default_value),
                Port_Authority=portdata.get('Port Authority', default_value),
                Phone=portdata.get('Phone', default_value),
                Fax=portdata.get('Fax', default_value),
                Email=portdata.get('Email', default_value),
                Coordinates=portdata.get('Coordinates', default_value),
                Port_Type=portdata.get('Port Type', default_value),
                Port_Size=portdata.get('Port Size', default_value),
                Website=portdata.get('Website', default_value),
                Terminal=portdata.get('Terminal', default_value),
            )
            db_session.add(portdatadb)
            db_session.commit()  
        else:
            print(f'[*] This Port : {port} Exists. Skipping...')
# Out:
# [*] Data for : Afghanistan
# **************************************************
# [*] This Port : {'ckey': 'kabul_af', 'name': 'Kabul'} Exists. Skipping...
# [*] Data for : Albania
# **************************************************
# [*] This Port : {'ckey': 'durres_al', 'name': 'Durres'} Exists. Skipping...
# [*] This Port : {'ckey': 'sarande_al', 'name': 'Sarande'} Exists. Skipping...
# [*] This Port : {'ckey': 'shengjin_al', 'name': 'Shengjin'} Exists. Skipping...
# [*] This Port : {'ckey': 'valona_al', 'name': 'Valona'} Exists. Skipping...
# [*] This Port : {'ckey': 'vlore_al', 'name': 'Vlore'} Exists. Skipping...
# [*] Data for : Algeria
# **************************************************
# [*] This Port : {'ckey': 'algeria_dz', 'name': 'Algeria'} Exists. Skipping...
# [*] This Port : {'ckey': 'annaba_dz', 'name': 'Annaba'} Exists. Skipping...
# [*] This Port : {'ckey': 'arzew_dz', 'name': 'Arzew'} Exists. Skipping...
# [*] This Port : {'ckey': 'arzew_el_djedid_dz', 'name': 'Arzew El-Djedid'} Exists. Skipping...
# [*] This Port : {'ckey': 'bejaia_dz', 'name': 'Bejaia'} Exists. Skipping...
# [*] This Port : {'ckey': 'benisaf_dz', 'name': 'Benisaf'} Exists. Skipping...
# [*] This Port : {'ckey': 'beni_saf_dz', 'name': 'Beni Saf'} Exists. Skipping...
# [*] This Port : {'ckey': 'cherchell_dz', 'name': 'Cherchell'} Exists. Skipping...
# [*] This Port : {'ckey': 'collo_dz', 'name': 'Collo'} Exists. Skipping...
# [*] This Port : {'ckey': 'dellys_dz', 'name': 'Dellys'} Exists. Skipping...
# [*] This Port : {'ckey': 'djazair_dz', 'name': 'Djazair'} Exists. Skipping...
# [*] This Port : {'ckey': 'djen_djen_dz', 'name': 'Djen-Djen'} Exists. Skipping...
# [*] This Port : {'ckey': 'ghazaouet_dz', 'name': 'Ghazaouet'} Exists. Skipping...
# [*] This Port : {'ckey': 'jijel_dz', 'name': 'Jijel'} Exists. Skipping...
# [*] This Port : {'ckey': 'mestghanem_dz', 'name': 'Mestghanem'} Exists. Skipping...
# [*] This Port : {'ckey': 'mostaganem_dz', 'name': 'Mostaganem'} Exists. Skipping...
# [*] This Port : {'ckey': 'oran_dz', 'name': 'Oran'} Exists. Skipping...
# [*] This Port : {'ckey': 'port_methanier_dz', 'name': 'Port Methanier'} Exists. Skipping...
# [*] This Port : {'ckey': 'skikda_dz', 'name': 'Skikda'} Exists. Skipping...
# [*] This Port : {'ckey': 'tenes_dz', 'name': 'Tenes'} Exists. Skipping...
# [*] Data for : American Samoa
# **************************************************
# [*] This Port : {'ckey': 'pago_pago_as', 'name': 'Pago Pago'} Exists. Skipping...
# [*] Data for : Angola
# **************************************************
# [*] This Port : {'ckey': 'ambriz_ao', 'name': 'Ambriz'} Exists. Skipping...
# [*] This Port : {'ckey': 'cabinda_ao', 'name': 'Cabinda'} Exists. Skipping...
# [*] This Port : {'ckey': 'essungo_marine_terminal_ao', 'name': 'Essungo Marine Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'futila_terminal_ao', 'name': 'Futila Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'girassol_terminal_ao', 'name': 'Girassol Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'kiabo_marine_terminal_ao', 'name': 'Kiabo Marine Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'kiame_marine_terminal_ao', 'name': 'Kiame Marine Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'lobito_ao', 'name': 'Lobito'} Exists. Skipping...
# [*] This Port : {'ckey': 'lombo_marine_terminal_ao', 'name': 'Lombo Marine Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'luanda_ao', 'name': 'Luanda'} Exists. Skipping...
# [*] This Port : {'ckey': 'malongo_terminal_ao', 'name': 'Malongo Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'mocamedes_ao', 'name': 'Mocamedes'} Exists. Skipping...
# [*] This Port : {'ckey': 'palanca_terminal_ao', 'name': 'Palanca Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'porto_amboim_ao', 'name': 'Porto Amboim'} Exists. Skipping...
# [*] This Port : {'ckey': 'soyo_ao', 'name': 'Soyo'} Exists. Skipping...
# [*] This Port : {'ckey': 'sumbe_ao', 'name': 'Sumbe'} Exists. Skipping...
# [*] This Port : {'ckey': 'takula_terminal_ao', 'name': 'Takula Terminal'} Exists. Skipping...
# [*] Data for : Antigua and Barbuda
# **************************************************
# [*] This Port : {'ckey': 'st_johns_ag', 'name': 'St. Johns'} Exists. Skipping...
# [*] Data for : Argentina
# **************************************************
# [*] This Port : {'ckey': 'arroyo_seco_ar', 'name': 'Arroyo Seco'} Exists. Skipping...
# [*] This Port : {'ckey': 'atucha_ar', 'name': 'Atucha'} Exists. Skipping...
# [*] This Port : {'ckey': 'bahia_blanca_ar', 'name': 'Bahia Blanca'} Exists. Skipping...
# [*] This Port : {'ckey': 'buenos_aires_ar', 'name': 'Buenos Aires'} Exists. Skipping...
# [*] This Port : {'ckey': 'caleta_paula_ar', 'name': 'Caleta Paula'} Exists. Skipping...
# [*] This Port : {'ckey': 'campana_ar', 'name': 'Campana'} Exists. Skipping...
# [*] This Port : {'ckey': 'comodoro_rivadacomod_ar', 'name': 'Comodoro Rivadacomod'} Exists. Skipping...
# [*] This Port : {'ckey': 'concepcion_ar', 'name': 'Concepcion'} Exists. Skipping...
# [*] This Port : {'ckey': 'deseado_ar', 'name': 'Deseado'} Exists. Skipping...
# [*] This Port : {'ckey': 'diamante_ar', 'name': 'Diamante'} Exists. Skipping...
# [*] This Port : {'ckey': 'ensenada_ar', 'name': 'Ensenada'} Exists. Skipping...
# [*] This Port : {'ckey': 'ibicuy_ar', 'name': 'Ibicuy'} Exists. Skipping...
# [*] This Port : {'ckey': 'la_plata_ar', 'name': 'La Plata'} Exists. Skipping...
# [*] This Port : {'ckey': 'mar_del_plata_ar', 'name': 'Mar del Plata'} Exists. Skipping...
# [*] This Port : {'ckey': 'puerto_deseado_ar', 'name': 'Puerto Deseado'} Exists. Skipping...
# [*] This Port : {'ckey': 'puerto_madryn_ar', 'name': 'Puerto Madryn'} Exists. Skipping...
# [*] This Port : {'ckey': 'stag_marine_terminal_au', 'name': 'Stag Marine Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'stanley_au', 'name': 'Stanley'} Exists. Skipping...
# [*] This Port : {'ckey': 'strahan_au', 'name': 'Strahan'} Exists. Skipping...
# [*] This Port : {'ckey': 'sydney_au', 'name': 'Sydney'} Exists. Skipping...
# [*] This Port : {'ckey': 'thevenard_au', 'name': 'Thevenard'} Exists. Skipping...
# [*] This Port : {'ckey': 'thursday_island_au', 'name': 'Thursday Island'} Exists. Skipping...
# [*] This Port : {'ckey': 'torres_strait_au', 'name': 'Torres Strait'} Exists. Skipping...
# [*] This Port : {'ckey': 'townsville_au', 'name': 'Townsville'} Exists. Skipping...
# [*] This Port : {'ckey': 'useless_loop_au', 'name': 'Useless Loop'} Exists. Skipping...
# [*] This Port : {'ckey': 'varanus_island_terminal_au', 'name': 'Varanus Island Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'wallaroo_au', 'name': 'Wallaroo'} Exists. Skipping...
# [*] This Port : {'ckey': 'wandoo_marine_terminal_au', 'name': 'Wandoo Marine Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'weipa_au', 'name': 'Weipa'} Exists. Skipping...
# [*] This Port : {'ckey': 'whyalla_au', 'name': 'Whyalla'} Exists. Skipping...
# [*] This Port : {'ckey': 'wyndham_au', 'name': 'Wyndham'} Exists. Skipping...
# [*] This Port : {'ckey': 'yamba_au', 'name': 'Yamba'} Exists. Skipping...
# [*] Data for : Austria
# **************************************************
# [*] This Port : {'ckey': 'enns_at', 'name': 'Enns'} Exists. Skipping...
# [*] This Port : {'ckey': 'linz_at', 'name': 'Linz'} Exists. Skipping...
# [*] This Port : {'ckey': 'salzburg_at', 'name': 'Salzburg'} Exists. Skipping...
# [*] This Port : {'ckey': 'vienna_at', 'name': 'Vienna'} Exists. Skipping...
# [*] This Port : {'ckey': 'wels_at', 'name': 'Wels'} Exists. Skipping...
# [*] This Port : {'ckey': 'wien_at', 'name': 'Wien'} Exists. Skipping...
# [*] Data for : Azerbaijan
# **************************************************
# [*] This Port : {'ckey': 'baku_az', 'name': 'Baku'} Exists. Skipping...
# [*] Data for : Bahamas
# **************************************************
# [*] This Port : {'ckey': 'freeport_bs', 'name': 'Freeport'} Exists. Skipping...
# [*] This Port : {'ckey': 'inagua_islands_bs', 'name': 'Inagua Islands'} Exists. Skipping...
# [*] This Port : {'ckey': 'nassau_bs', 'name': 'Nassau'} Exists. Skipping...
# [*] This Port : {'ckey': 'ocean_cay_bs', 'name': 'Ocean Cay'} Exists. Skipping...
# [*] This Port : {'ckey': 'south_riding_point_bs', 'name': 'South Riding Point'} Exists. Skipping...
# [*] Data for : Bahrain
# **************************************************
# [*] This Port : {'ckey': 'bahrain_bh', 'name': 'Bahrain'} Exists. Skipping...
# [*] This Port : {'ckey': 'mina_sulman_bh', 'name': 'Mina Sulman'} Exists. Skipping...
# [*] This Port : {'ckey': 'sitra_bh', 'name': 'Sitra'} Exists. Skipping...
# [*] Data for : Bangladesh
# **************************************************
# [*] This Port : {'ckey': 'chalna_bd', 'name': 'Chalna'} Exists. Skipping...
# [*] This Port : {'ckey': 'chittagong_bd', 'name': 'Chittagong'} Exists. Skipping...
# [*] This Port : {'ckey': 'dhaka_bd', 'name': 'Dhaka'} Exists. Skipping...
# [*] This Port : {'ckey': 'mongla_bd', 'name': 'Mongla'} Exists. Skipping...
# [*] Data for : Barbados
# **************************************************
# [*] This Port : {'ckey': 'bridgetown_bb', 'name': 'Bridgetown'} Exists. Skipping...
# [*] Data for : Belarus
# **************************************************
# [*] This Port : {'ckey': 'brest_by', 'name': 'Brest'} Exists. Skipping...
# [*] Data for : Belgium
# **************************************************
# [*] This Port : {'ckey': 'antwerpen_be', 'name': 'Antwerpen'} Exists. Skipping...
# [*] This Port : {'ckey': 'brussels_be', 'name': 'Brussels'} Exists. Skipping...
# [*] This Port : {'ckey': 'brussels_be', 'name': 'Brussels'} Exists. Skipping...
# [*] This Port : {'ckey': 'genk_be', 'name': 'Genk'} Exists. Skipping...
# [*] This Port : {'ckey': 'ghent_be', 'name': 'Ghent'} Exists. Skipping...
# [*] This Port : {'ckey': 'hemiksem_be', 'name': 'Hemiksem'} Exists. Skipping...
# [*] This Port : {'ckey': 'liege_be', 'name': 'Liege'} Exists. Skipping...
# [*] This Port : {'ckey': 'liege_be', 'name': 'Liege'} Exists. Skipping...
# [*] This Port : {'ckey': 'londerzeel_be', 'name': 'Londerzeel'} Exists. Skipping...
# [*] This Port : {'ckey': 'nieuwpoort_be', 'name': 'Nieuwpoort'} Exists. Skipping...
# [*] This Port : {'ckey': 'ostend_be', 'name': 'Ostend'} Exists. Skipping...
# [*] This Port : {'ckey': 'zeebgrugge_be', 'name': 'Zeebgrugge'} Exists. Skipping...
# [*] Data for : Belize
# **************************************************
# [*] This Port : {'ckey': 'belize_bz', 'name': 'Belize'} Exists. Skipping...
# [*] This Port : {'ckey': 'belize_city_bz', 'name': 'Belize City'} Exists. Skipping...
# [*] Data for : Benin
# **************************************************
# [*] This Port : {'ckey': 'cotonou_bj', 'name': 'Cotonou'} Exists. Skipping...
# [*] This Port : {'ckey': 'seme_terminal_bj', 'name': 'Seme Terminal'} Exists. Skipping...
# [*] Data for : Bermuda
# **************************************************
# [*] This Port : {'ckey': 'freeport_bm', 'name': 'Freeport'} Exists. Skipping...
# [*] This Port : {'ckey': 'hamilton_bm', 'name': 'Hamilton'} Exists. Skipping...
# [*] This Port : {'ckey': 'st_georges_bm', 'name': "St George's"} Exists. Skipping...
# [*] Data for : Bolivia
# **************************************************
# [*] This Port : {'ckey': 'san_pedro_bo', 'name': 'San Pedro'} Exists. Skipping...
# [*] Data for : Brazil
# **************************************************
# [*] This Port : {'ckey': 'alumar_br', 'name': 'Alumar'} Exists. Skipping...
# [*] This Port : {'ckey': 'angra_dos_reis_br', 'name': 'Angra dos Reis'} Exists. Skipping...
# [*] This Port : {'ckey': 'aracaju_br', 'name': 'Aracaju'} Exists. Skipping...
# [*] This Port : {'ckey': 'aracati_br', 'name': 'Aracati'} Exists. Skipping...
# **************************************************
# [*] This Port : {'ckey': 'balchik_bg', 'name': 'Balchik'} Exists. Skipping...
# [*] This Port : {'ckey': 'burgas_bg', 'name': 'Burgas'} Exists. Skipping...
# [*] This Port : {'ckey': 'kavarna_bg', 'name': 'Kavarna'} Exists. Skipping...
# [*] This Port : {'ckey': 'nessebar_bg', 'name': 'Nessebar'} Exists. Skipping...
# [*] This Port : {'ckey': 'sofia_bg', 'name': 'Sofia'} Exists. Skipping...
# [*] This Port : {'ckey': 'varna_bg', 'name': 'Varna'} Exists. Skipping...
# [*] Data for : Cambodia
# **************************************************
# [*] This Port : {'ckey': 'kampong_saom_kh', 'name': 'Kampong Saom'} Exists. Skipping...
# [*] This Port : {'ckey': 'phnom_penh_kh', 'name': 'Phnom Penh'} Exists. Skipping...
# [*] This Port : {'ckey': 'sihanoukville_kh', 'name': 'Sihanoukville'} Exists. Skipping...
# [*] Data for : Cameroon
# **************************************************
# [*] This Port : {'ckey': 'douala_cm', 'name': 'Douala'} Exists. Skipping...
# [*] This Port : {'ckey': 'ebome_marine_terminal_cm', 'name': 'Ebome Marine Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'garoua_cm', 'name': 'Garoua'} Exists. Skipping...
# [*] This Port : {'ckey': 'kole_terminal_cm', 'name': 'Kole Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'kribi_cm', 'name': 'Kribi'} Exists. Skipping...
# [*] This Port : {'ckey': 'limboh_terminal_cm', 'name': 'Limboh Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'moudi_terminal_cm', 'name': 'Moudi Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'tiko_cm', 'name': 'Tiko'} Exists. Skipping...
# [*] This Port : {'ckey': 'victoria_cm', 'name': 'Victoria'} Exists. Skipping...
# [*] Data for : Canada
# **************************************************
# [*] This Port : {'ckey': 'aklavik_ca', 'name': 'Aklavik'} Exists. Skipping...
# [*] This Port : {'ckey': 'amherst_ca', 'name': 'Amherst'} Exists. Skipping...
# [*] This Port : {'ckey': 'amherstburg_ca', 'name': 'Amherstburg'} Exists. Skipping...
# [*] This Port : {'ckey': 'annapolis_royal_ca', 'name': 'Annapolis Royal'} Exists. Skipping...
# [*] This Port : {'ckey': 'argentia_ca', 'name': 'Argentia'} Exists. Skipping...
# [*] This Port : {'ckey': 'arichat_ca', 'name': 'Arichat'} Exists. Skipping...
# [*] This Port : {'ckey': 'baddeck_ca', 'name': 'Baddeck'} Exists. Skipping...
# [*] This Port : {'ckey': 'baie_comeau_ca', 'name': 'Baie Comeau'} Exists. Skipping...
# [*] This Port : {'ckey': 'baie_verte_ca', 'name': 'Baie Verte'} Exists. Skipping...
# [*] This Port : {'ckey': 'bathurst_ca', 'name': 'Bathurst'} Exists. Skipping...
# [*] This Port : {'ckey': 'bay_roberts_ca', 'name': 'Bay Roberts'} Exists. Skipping...
# [*] This Port : {'ckey': 'bayside_ca', 'name': 'Bayside'} Exists. Skipping...
# [*] This Port : {'ckey': 'beaver_harbour_ca', 'name': 'Beaver Harbour'} Exists. Skipping...
# [*] This Port : {'ckey': 'springdale_ca', 'name': 'Springdale'} Exists. Skipping...
# [*] This Port : {'ckey': 'squamish_ca', 'name': 'Squamish'} Exists. Skipping...
# [*] This Port : {'ckey': 'st_anthony_ca', 'name': 'St Anthony'} Exists. Skipping...
# [*] This Port : {'ckey': 'stephenville_ca', 'name': 'Stephenville'} Exists. Skipping...
# [*] This Port : {'ckey': 'stewart_ca', 'name': 'Stewart'} Exists. Skipping...
# [*] This Port : {'ckey': 'st_john_ca', 'name': 'St. John'} Exists. Skipping...
# [*] This Port : {'ckey': 'st_johns_ca', 'name': "St John's"} Exists. Skipping...
# [*] This Port : {'ckey': 'st_lawrence_ca', 'name': 'St. Lawrence'} Exists. Skipping...
# [*] This Port : {'ckey': 'st_romuald_ca', 'name': 'St Romuald'} Exists. Skipping...
# [*] This Port : {'ckey': 'summerside_ca', 'name': 'Summerside'} Exists. Skipping...
# [*] This Port : {'ckey': 'sydney_ca', 'name': 'Sydney'} Exists. Skipping...
# [*] This Port : {'ckey': 'tahsis_ca', 'name': 'Tahsis'} Exists. Skipping...
# [*] This Port : {'ckey': 'texada_island_ca', 'name': 'Texada Island'} Exists. Skipping...
# [*] This Port : {'ckey': 'thunder_bay_ca', 'name': 'Thunder Bay'} Exists. Skipping...
# [*] This Port : {'ckey': 'tillsonburg_ca', 'name': 'Tillsonburg'} Exists. Skipping...
# [*] This Port : {'ckey': 'toronto_ca', 'name': 'Toronto'} Exists. Skipping...
# [*] This Port : {'ckey': 'trenton_ca', 'name': 'Trenton'} Exists. Skipping...
# [*] This Port : {'ckey': 'trois_rivieres_ca', 'name': 'Trois-Rivieres'} Exists. Skipping...
# [*] This Port : {'ckey': 'tuktoyaktuk_ca', 'name': 'Tuktoyaktuk'} Exists. Skipping...
# [*] This Port : {'ckey': 'twillingate_ca', 'name': 'Twillingate'} Exists. Skipping...
# [*] This Port : {'ckey': 'valleyfield_ca', 'name': 'Valleyfield'} Exists. Skipping...
# [*] This Port : {'ckey': 'vancouver_ca', 'name': 'Vancouver'} Exists. Skipping...
# [*] This Port : {'ckey': 'vancouver_centerm_terminal_ca', 'name': 'Vancouver Centerm Terminal'} Exists. Skipping...
# [*] This Port : {'ckey': 'victoria_ca', 'name': 'Victoria'} Exists. Skipping...
# [*] This Port : {'ckey': 'wabush_ca', 'name': 'Wabush'} Exists. Skipping...
# [*] This Port : {'ckey': 'watson_island_ca', 'name': 'Watson Island'} Exists. Skipping...
# [*] This Port : {'ckey': 'welland_ca', 'name': 'Welland'} Exists. Skipping...
# [*] This Port : {'ckey': 'weymouth_ca', 'name': 'Weymouth'} Exists. Skipping...
# [*] This Port : {'ckey': 'wheatley_ca', 'name': 'Wheatley'} Exists. Skipping...
# [*] This Port : {'ckey': 'winchester_ca', 'name': 'Winchester'} Exists. Skipping...
# [*] This Port : {'ckey': 'windsor_ca', 'name': 'Windsor'} Exists. Skipping...
# [*] This Port : {'ckey': 'winnipeg_ca', 'name': 'Winnipeg'} Exists. Skipping...
# [*] This Port : {'ckey': 'woodfibre_ca', 'name': 'Woodfibre'} Exists. Skipping...
# [*] This Port : {'ckey': 'yarmouth_ca', 'name': 'Yarmouth'} Exists. Skipping...
# [*] Data for : Cape Verde
# **************************************************
# [*] This Port : {'ckey': 'porto_grande_cv', 'name': 'Porto Grande'} Exists. Skipping...
# [*] This Port : {'ckey': 'porto_praia_cv', 'name': 'Porto Praia'} Exists. Skipping...
# [*] This Port : {'ckey': 'sal_island_cv', 'name': 'Sal Island'} Exists. Skipping...
# [*] Data for : Cayman Islands
# **************************************************
# [*] This Port : {'ckey': 'cayman_brac_ky', 'name': 'Cayman Brac'} Exists. Skipping...
# [*] This Port : {'ckey': 'georgetown_ky', 'name': 'Georgetown'} Exists. Skipping...
# [*] Data for : Chile
# **************************************************
# [*] This Port : {'ckey': 'ancud_cl', 'name': 'Ancud'} Exists. Skipping...
# [*] This Port : {'ckey': 'antofagasta_cl', 'name': 'Antofagasta'} Exists. Skipping...
# [*] This Port : {'ckey': 'arica_cl', 'name': 'Arica'} Exists. Skipping...
# [*] This Port : {'ckey': 'balmaceda_cl', 'name': 'Balmaceda'} Exists. Skipping...
# [*] This Port : {'ckey': 'barquito_cl', 'name': 'Barquito'} Exists. Skipping...
# [*] This Port : {'ckey': 'cabo_negro_cl', 'name': 'Cabo Negro'} Exists. Skipping...
# [*] This Port : {'ckey': 'caldera_cl', 'name': 'Caldera'} Exists. Skipping...
# [*] This Port : {'ckey': 'calderilla_cl', 'name': 'Calderilla'} Exists. Skipping...
# [*] This Port : {'ckey': 'caleta_barquito_cl', 'name': 'Caleta Barquito'} Exists. Skipping...
# [*] This Port : {'ckey': 'caleta_coloso_cl', 'name': 'Caleta Coloso'} Exists. Skipping...
# [*] This Port : {'ckey': 'caleta_patillos_cl', 'name': 'Caleta Patillos'} Exists. Skipping...
# [*] This Port : {'ckey': 'castro_cl', 'name': 'Castro'} Exists. Skipping...
# [*] This Port : {'ckey': 'chacabuco_cl', 'name': 'Chacabuco'} Exists. Skipping...
# [*] This Port : {'ckey': 'coquimbo_cl', 'name': 'Coquimbo'} Exists. Skipping...
# [*] This Port : {'ckey': 'coronel_cl', 'name': 'Coronel'} Exists. Skipping...
# [*] This Port : {'ckey': 'corral_cl', 'name': 'Corral'} Exists. Skipping...
# [*] This Port : {'ckey': 'cruz_grande_cl', 'name': 'Cruz Grande'} Exists. Skipping...
# [*] This Port : {'ckey': 'easter_island_cl', 'name': 'Easter Island'} Exists. Skipping...
# [*] This Port : {'ckey': 'guayacan_cl', 'name': 'Guayacan'} Exists. Skipping...
# [*] This Port : {'ckey': 'huasco_cl', 'name': 'Huasco'} Exists. Skipping...
# [*] This Port : {'ckey': 'iquique_cl', 'name': 'Iquique'} Exists. Skipping...
# [*] This Port : {'ckey': 'isla_de_pascua_cl', 'name': 'Isla de Pascua'} Exists. Skipping...
# [*] This Port : {'ckey': 'isla_guarello_cl', 'name': 'Isla Guarello'} Exists. Skipping...
# [*] This Port : {'ckey': 'la_chimba_cove_cl', 'name': 'La Chimba Cove'} Exists. Skipping...
# [*] Scraping Port : The Dalles
# [*] Scraping Port : Thorne Bay
# [*] Scraping Port : Three Forks
# [*] Scraping Port : Toledo
# [*] Scraping Port : Tongue Point
# [*] Scraping Port : Trainer
# [*] Scraping Port : Trout River
# [*] Scraping Port : Tryon
# [*] Scraping Port : Tucker
# [*] Scraping Port : Tucson
# [*] Scraping Port : Tulsa
# [*] Scraping Port : Turkey
# [*] Scraping Port : Tuscumbia
# [*] Scraping Port : Tyler
# [*] Scraping Port : Umatilla
# [*] Scraping Port : Vancouver
# [*] Scraping Port : Veblen
# [*] Scraping Port : Venice
# [*] Scraping Port : Vernon Hills
# [*] Scraping Port : Waddington
# [*] Scraping Port : Wadesboro
# [*] Scraping Port : Walhalla
# [*] Scraping Port : Walla Walla
# [*] Scraping Port : Walnut Grove
# [*] Scraping Port : Walpole
# [*] Scraping Port : Walworth
# [*] Scraping Port : Waukegan
# [*] Scraping Port : Wellsburg
# [*] Scraping Port : Wendover
# [*] Scraping Port : West Chicago
# [*] Scraping Port : West Groton
# [*] Scraping Port : Whitman County
# [*] Scraping Port : Whittier
# [*] Scraping Port : Wichita Falls
# [*] Scraping Port : Wilburton
# [*] Scraping Port : Willapa
# [*] Scraping Port : Willcox
# [*] Scraping Port : Williamson
# [*] Scraping Port : Willow
# [*] Scraping Port : Wilmington
# [*] Scraping Port : Winston Salem
# [*] Scraping Port : Winterport
# [*] Scraping Port : Woodbridge
# [*] Scraping Port : Wood-Ridge
# [*] Scraping Port : Wrangell
# [*] Scraping Port : Wyandotte
# [*] Scraping Port : Wytheville
# [*] Scraping Port : Yakutat
# [*] Scraping Port : Yarmouth
# [*] Scraping Port : Yorktown
# [*] Scraping Port : Yuma
# [*] Scraping Port : Zeeland
# [*] Data for : United States Minor Outlying Islands
# **************************************************
# [*] Added to Database :  <__main__.Country object at 0x00000200C9C89AE0>
# [*] Scraping Port : Wake Island
# [*] Data for : Uruguay
# **************************************************
# [*] Added to Database :  <__main__.Country object at 0x00000200C9C89AE0>
# [*] Scraping Port : Colonia
# [*] Scraping Port : Fray Bentos
# [*] Scraping Port : Jose Ignacio Terminal
# [*] Scraping Port : La Paloma
# [*] Scraping Port : Montevideo
# [*] Scraping Port : Punta del Este
# [*] Data for : U.S. Virgin Islands
# **************************************************
# [*] Added to Database :  <__main__.Country object at 0x00000200C9484CA0>
# [*] Scraping Port : Charlotte Amalie
# [*] Scraping Port : Christiansted, St. Croix
# [*] Scraping Port : Limetree Bay
# [*] Scraping Port : Port Alucroix
# [*] Scraping Port : Third Port
# [*] Data for : Uzbekistan
# **************************************************
# [*] Added to Database :  <__main__.Country object at 0x00000200C9984B80>
# [*] Scraping Port : Bukhara
# [*] Scraping Port : Tashkent
# [*] Data for : Vanuatu
# **************************************************
# [*] Added to Database :  <__main__.Country object at 0x00000200C9403B20>
# [*] Scraping Port : Port Vila
# [*] Scraping Port : Santo
# [*] Data for : Venezuela
# **************************************************
# [*] Added to Database :  <__main__.Country object at 0x00000200C9486E90>
# [*] Scraping Port : Alcasa
# [*] Scraping Port : Amuay
# [*] Scraping Port : Araya
# [*] Scraping Port : Bajo Grande Refinery
# [*] Scraping Port : Boca Grande
# [*] Scraping Port : Borburata
# [*] Scraping Port : Cabimas/Maracaibo L
# [*] Scraping Port : Carupano
# [*] Scraping Port : Chichiriviche
# [*] Scraping Port : Ciudad Bolivar
# [*] Scraping Port : Coloncha
# [*] Scraping Port : Cristobal Colon
# [*] Scraping Port : Cumana
# [*] Scraping Port : El Chaure
# [*] Scraping Port : El Guamache
# [*] Scraping Port : El Palito
# [*] Scraping Port : El Tablazo/Maracaibo
# [*] Scraping Port : Guanta
# [*] Scraping Port : Guaraguao
# [*] Scraping Port : Guaranao Bay
# [*] Scraping Port : Guiria
# [*] Scraping Port : Jose Terminal
# [*] Scraping Port : La Ceiba
# [*] Scraping Port : La Estacada
# [*] Scraping Port : La Guaira
# [*] Scraping Port : Maracaibo
# [*] Scraping Port : Matanzas
# [*] Scraping Port : Palua
# [*] Scraping Port : Pamatacual
# [*] Scraping Port : Paradero
# [*] Scraping Port : Pertigalete
# [*] Scraping Port : Puerto Cabello
# [*] Scraping Port : Puerto de Hierro
# [*] Scraping Port : Puerto Pedernales
# [*] Scraping Port : Puerto Sucre
# [*] Scraping Port : Punta Camacho
# [*] Scraping Port : Punta Cardon
# [*] Scraping Port : Punta Cuchillo
# [*] Scraping Port : Punta de Palmas
# [*] Scraping Port : San Felix
# [*] Scraping Port : San Lorenzo
# [*] Scraping Port : Venalum Terminal
# [*] Scraping Port : Venterminales
# [*] Data for : Vietnam
# **************************************************
# [*] Added to Database :  <__main__.Country object at 0x00000200C9486E90>
# [*] Scraping Port : Ba Ngoi
# [*] Scraping Port : Binh Duong Port
# [*] Scraping Port : Cai Lan
# [*] Scraping Port : Cai Mep
# [*] Scraping Port : Campha
# [*] Scraping Port : Can Tho
# [*] Scraping Port : Cat Lai
# [*] Scraping Port : Dai Hung
# [*] Scraping Port : Danang
# [*] Scraping Port : Da Nang
# [*] Scraping Port : Dong Nai Port
# [*] Scraping Port : Dong Thap
# [*] Scraping Port : Haiphong
# [*] Scraping Port : Hanoi
# [*] Scraping Port : Ho Chi Minh City
# [*] Scraping Port : Hon Chong
# [*] Scraping Port : Hon Gay
# [*] Scraping Port : Le Mon
# [*] Scraping Port : My Tho
# [*] Scraping Port : Nam Can
# [*] Scraping Port : Nghe Tinh
# [*] Scraping Port : Nha Trang
# [*] Scraping Port : Phu My
# [*] Scraping Port : Quy Nhon
# [*] Scraping Port : Tan Cang
# [*] Scraping Port : Van Phong Bay
# [*] Scraping Port : Vung Tau
# [*] Data for : Yemen
# **************************************************
# [*] Added to Database :  <__main__.Country object at 0x00000200C9486E90>
# [*] Scraping Port : Aden
# [*] Scraping Port : Hodeidah
# [*] Scraping Port : Mokha
# [*] Scraping Port : Mukalla
# [*] Scraping Port : Nishtun
# [*] Scraping Port : Ras Isa Marine Terminal
# [*] Scraping Port : Saleef Port
# [*] Data for : Zimbabwe
# **************************************************
# [*] Added to Database :  <__main__.Country object at 0x00000200C9486E90>
# [*] Scraping Port : Harare
